# %%
import pandas as pd

# Load your raw CSV
df = pd.read_csv("C:\Project\student-performance-analyzer\StudentsPerformance.csv")

# Fix column names (your CSV uses slightly weird headers)
df.columns = [
    "gender",
    "race_ethnicity",
    "parental_level_of_education",
    "lunch",
    "test_preparation_course",
    "math_score",
    "reading_score",
    "writing_score"
]

# One-hot encode exactly like before training your model
df_encoded = pd.get_dummies(df)

# Save encoded version for Streamlit
df_encoded.to_csv("train_encoded.csv", index=False)

df_encoded.head()
# Out:
#    math_score  reading_score  writing_score  gender_female  gender_male  \
# 0          72             72             74           True        False
# 1          69             90             88           True        False
# 2          90             95             93           True        False
# 3          47             57             44          False         True
# 4          76             78             75          False         True
#
#    race_ethnicity_group A  race_ethnicity_group B  race_ethnicity_group C  \
# 0                   False                    True                   False
# 1                   False                   False                    True
# 2                   False                    True                   False
# 3                    True                   False                   False
# 4                   False                   False                    True
#
#    race_ethnicity_group D  race_ethnicity_group E  \
# ...
